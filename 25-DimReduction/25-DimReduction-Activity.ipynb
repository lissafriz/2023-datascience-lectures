# %% [markdown]
# # Introduction to Data Science
# # Lecture 25: Dimension Reduction - Activity
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*

# %%
# imports and setup 

import numpy as np

import pandas as pd
pd.set_option('display.notebook_repr_html', False)

from sklearn.datasets import load_iris, load_digits
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn import metrics
from sklearn.metrics import homogeneity_score, v_measure_score

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.style.use('ggplot')

import seaborn as sns

# %% [markdown]
# In this activity we will consider an RNA data set taken from [here](https://www.nature.com/articles/s41592-019-0425-8). This data set contains genetic information on 296 different cells, recording 3000 distinct gene counts/features for each cell. The cells were synthetically generated in various mixtures (7 different cell types) so that ground truth cell type information is in fact available. Note this data has already been imputed and scaled, so you don't need to rescale.

# %%
# Read in the data

rna_data = pd.read_csv("rnamix1_SCT.csv")
rna_labels = pd.read_csv("rnamix1_labels.csv",index_col=0)
print(rna_data.info())
print(rna_data.head())
rna_labels
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Columns: 3000 entries, ENSG00000019582 to ENSG00000116560
# dtypes: float64(3000)
# memory usage: 6.8 MB
# None
#    ENSG00000019582  ENSG00000132432  ENSG00000234745  ENSG00000146648  \
# 0         4.317488         3.135494         4.382027         2.397895
# 1         3.258097         4.382027         3.135494         3.688879
# 2         3.465736         4.844187         3.496508         4.007333
# 3         3.332205         5.017280         3.465736         4.025352
# 4         3.332205         5.111988         3.526361         4.060443
#
#    ENSG00000108602  ERCC-00130  ERCC-00096  ERCC-00002  ERCC-00046  \
# 0         3.806662    3.713572    3.496508    3.610918    2.995732
# 1         2.564949    5.043425    4.836282    4.875197    4.077537
# 2         2.890372    4.442651    4.110874    4.262680    3.433987
# 3         2.890372    4.369448    4.094345    4.262680    3.465736
# 4         2.833213    4.406719    4.143135    4.234107    3.496508
#
#    ERCC-00074  ...  ENSG00000197619  ENSG00000114450  ENSG00000147592  \
# 0    3.663562  ...              0.0         1.386294         1.386294
# 1    4.844187  ...              0.0         0.693147         1.386294
# 2    4.219508  ...              0.0         0.693147         1.609438
# 3    4.204693  ...              0.0         1.098612         1.945910
# 4    4.234107  ...              0.0         1.098612         1.098612
#
#    ENSG00000184897  ENSG00000157765  ENSG00000116273  ENSG00000000003  \
# 0         2.302585         0.693147         0.000000         1.098612
# 1         2.079442         0.000000         0.000000         1.098612
# 2         2.197225         0.000000         0.000000         1.386294
# 3         2.302585         0.000000         0.000000         1.098612
# 4         2.484907         0.000000         0.693147         1.098612
#
#    ENSG00000250120  ENSG00000069122  ENSG00000116560
# 0         0.000000         0.693147         2.890372
# 1         0.000000         0.693147         2.772589
# 2         0.000000         0.000000         2.639057
# 3         0.000000         0.000000         2.772589
# 4         0.693147         0.693147         2.833213
#
# [5 rows x 3000 columns]
#             CellType
# CellNumber
# 1                  1
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# ...              ...
# 292                7
# 293                7
# 294                7
# 295                7
# 296                7
#
# [296 rows x 1 columns]

# %% [markdown]
# (1) Make a 2-dimensional PCA plot of the data, and color it by the cell types.

# %%
# Your code goes here
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF', '000000', '#000000', '#FF00FF', '#FF0000'])

pca_model = PCA()
X_PCA = pca_model.fit_transform(rna_data)

plt.scatter(X_PCA[:, 0], X_PCA[:, 1], c = rna_labels['CellType'], cmap = cmap_bold, s=30)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# (2) What percentage of the variance is captured by the first 2 PC's? Make a plot showing the decay of the variance explained by the first 100 PC's. How many PC's would you need to capture 90% of the variance?

# %%
# Your code goes here
var_ratio = pca_model.explained_variance_ratio_
print(var_ratio)

plt.plot(np.linspace(1, 100, num = 296), var_ratio, '--')

plt.ylabel('Proportion of Variance Explained')
plt.xlabel('Principal Component')
plt.xlim(0.75,4.25)
plt.ylim(0,0.5)
plt.xticks(np.linspace(1, 100, num = 19))
plt.show()
# Out:
# [2.76456119e-01 6.70078902e-02 3.15827691e-02 1.21257136e-02
#  9.45516509e-03 6.76412797e-03 5.45229706e-03 4.92908544e-03
#  4.69705368e-03 4.45836248e-03 4.24097249e-03 4.09819393e-03
#  4.04083208e-03 3.98434129e-03 3.89764362e-03 3.86767110e-03
#  3.85160624e-03 3.83208954e-03 3.76831638e-03 3.74598710e-03
#  3.70035838e-03 3.65089982e-03 3.60135488e-03 3.57732487e-03
#  3.56288059e-03 3.52845195e-03 3.51770654e-03 3.51209604e-03
#  3.49604872e-03 3.47123437e-03 3.44264893e-03 3.38996850e-03
#  3.37995499e-03 3.34733874e-03 3.32881484e-03 3.31622703e-03
#  3.28514328e-03 3.27205030e-03 3.26238409e-03 3.24097131e-03
#  3.21485160e-03 3.19399775e-03 3.17837058e-03 3.17028185e-03
#  3.13389188e-03 3.11575568e-03 3.10212405e-03 3.09066404e-03
#  3.08328682e-03 3.07409488e-03 3.05648673e-03 3.04289997e-03
#  3.03119225e-03 3.00872959e-03 2.98607127e-03 2.97486883e-03
#  2.93895118e-03 2.92933938e-03 2.91612491e-03 2.90254047e-03
#  2.89628054e-03 2.87382965e-03 2.86950102e-03 2.85893956e-03
#  2.84485389e-03 2.83403717e-03 2.81648113e-03 2.79745009e-03
#  2.77475316e-03 2.76891993e-03 2.74686600e-03 2.74337416e-03
#  2.73406476e-03 2.71256120e-03 2.69879358e-03 2.68236376e-03
#  2.66536809e-03 2.65095043e-03 2.63877679e-03 2.62467088e-03
#  2.61205088e-03 2.59970424e-03 2.59251053e-03 2.58207587e-03
#  2.57213649e-03 2.56792722e-03 2.55153560e-03 2.54683344e-03
#  2.53680438e-03 2.50993535e-03 2.49663276e-03 2.49310162e-03
#  2.48063442e-03 2.47441667e-03 2.46161842e-03 2.44321439e-03
#  2.43637824e-03 2.43130708e-03 2.40948968e-03 2.40391554e-03
#  2.38564555e-03 2.37659243e-03 2.37100608e-03 2.35895737e-03
#  2.34692220e-03 2.34133005e-03 2.32426034e-03 2.31693215e-03
#  2.30962426e-03 2.29421859e-03 2.28638881e-03 2.27554084e-03
#  2.27199736e-03 2.26049773e-03 2.24232068e-03 2.23618816e-03
#  2.22788634e-03 2.21696668e-03 2.19541814e-03 2.19241781e-03
#  2.18474675e-03 2.16856864e-03 2.16752092e-03 2.15431634e-03
#  2.14856663e-03 2.14611908e-03 2.12655316e-03 2.11353671e-03
#  2.10798007e-03 2.09703807e-03 2.07914345e-03 2.07013242e-03
#  2.05769670e-03 2.04559399e-03 2.04215976e-03 2.03454533e-03
#  2.02549454e-03 2.01385204e-03 2.01180646e-03 1.99671825e-03
#  1.99262466e-03 1.97812215e-03 1.97514143e-03 1.96584143e-03
#  1.94894037e-03 1.94132136e-03 1.93249798e-03 1.92361638e-03
#  1.92040292e-03 1.91197975e-03 1.90607922e-03 1.88578982e-03
#  1.88273586e-03 1.87687600e-03 1.86884409e-03 1.85435568e-03
#  1.85288703e-03 1.84720079e-03 1.83517094e-03 1.82918151e-03
#  1.81460037e-03 1.80644289e-03 1.79433412e-03 1.78871926e-03
#  1.77929268e-03 1.76855745e-03 1.76695614e-03 1.76305978e-03
#  1.75048482e-03 1.73624167e-03 1.72491193e-03 1.72445596e-03
#  1.71076424e-03 1.70159537e-03 1.69201208e-03 1.68867938e-03
#  1.67922747e-03 1.67677865e-03 1.65949354e-03 1.65448271e-03
#  1.64891820e-03 1.64065127e-03 1.63501735e-03 1.62554896e-03
#  1.62456309e-03 1.61534174e-03 1.60994239e-03 1.60036634e-03
#  1.59209936e-03 1.58928876e-03 1.57902209e-03 1.57223890e-03
#  1.55942043e-03 1.55090385e-03 1.53863518e-03 1.53112743e-03
#  1.52566887e-03 1.52341920e-03 1.51404404e-03 1.50489925e-03
#  1.49795167e-03 1.49020455e-03 1.48986566e-03 1.48570263e-03
#  1.47052662e-03 1.46379313e-03 1.45565346e-03 1.44862489e-03
#  1.43668409e-03 1.43211756e-03 1.42402821e-03 1.42015538e-03
#  1.41063880e-03 1.40303392e-03 1.39354466e-03 1.38206959e-03
#  1.37356286e-03 1.37209162e-03 1.36116990e-03 1.36090183e-03
#  1.35369475e-03 1.34627969e-03 1.34047894e-03 1.33636147e-03
#  1.32700333e-03 1.31750517e-03 1.31544988e-03 1.30502658e-03
#  1.30222897e-03 1.29121412e-03 1.28548428e-03 1.28043955e-03
#  1.26826527e-03 1.26344605e-03 1.26088008e-03 1.25409525e-03
#  1.24276114e-03 1.23953415e-03 1.23673321e-03 1.23041339e-03
#  1.21856143e-03 1.20629712e-03 1.20022844e-03 1.19392319e-03
#  1.19041269e-03 1.18226053e-03 1.17240485e-03 1.16796257e-03
#  1.15708599e-03 1.15186604e-03 1.13930169e-03 1.13697375e-03
#  1.12298911e-03 1.12006454e-03 1.10960928e-03 1.10588519e-03
#  1.10071150e-03 1.09583125e-03 1.09050062e-03 1.07854440e-03
#  1.06818397e-03 1.05948642e-03 1.05643994e-03 1.05300272e-03
#  1.04327309e-03 1.03341335e-03 1.02738911e-03 1.02221536e-03
#  1.01260738e-03 1.00420841e-03 9.95958238e-04 9.85994404e-04
#  9.81273668e-04 9.70861815e-04 9.67178807e-04 9.58068658e-04
#  9.55285611e-04 9.47032566e-04 9.31619282e-04 9.29084618e-04
#  9.21583476e-04 9.16065114e-04 9.13793182e-04 9.05041237e-04
#  9.02519254e-04 8.85152737e-04 8.78029294e-04 8.70034903e-04
#  8.58030010e-04 8.44584237e-04 8.36300876e-04 8.22402399e-04
#  8.12421105e-04 7.99243797e-04 7.86495753e-04 2.79813068e-31]

# %% [markdown]
# (3) Calculate the v_measure_score obtained by running kmeans with k = 7 on the 2-dimensional PCA plot. Can you achieve a higher score by using more PCs?

# %%
# Your code goes here
X_PCA = PCA(n_components=5).fit_transform(rna_data)
kmeans_model = KMeans(init='k-means++', n_clusters=7, n_init=10,random_state=1)
kmeans_model.fit(X_PCA)
metric = metrics.v_measure_score(labels_true=rna_labels['CellType'], labels_pred=kmeans_model.labels_)
print(metric)
# Out:
# 0.9023402958987059
