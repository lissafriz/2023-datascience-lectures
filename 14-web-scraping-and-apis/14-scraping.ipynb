# %% [markdown]
# # Introduction to Data Science – Lecture 14 – Web Scraping
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*
#
# In this lecture we will explore how we can extract data from a web-page using automatic scraping and crawling with [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# First, we'll talk a bit about HTML though.

# %% [markdown]
# ## HTML and the DOM
#
# We will scrape web-pages that are (partially) written in HTML and represented in the DOM. DOM stands for  Document Object Model, while HTML stands for “HyperText Markup Language”. 30 years ago, that used to be a meaningful description of what HTML actually did: it has links (hypertext), and it is a markup language. The latest version of HTML, however, the HTML5 standard, does much, much more: graphics, audio, video, etc. So it is easier to think of HTML as “whatever it is that web browsers know how to interpret”, and just not think about the actual term.

# %% [markdown]
# ### Elements
#
# The important thing about HTML is that the markup is represented by elements. An HTML element is a portion of the content that is surrounded by a pair of tags of the same name. Like this:
#
# ```html
# <strong>This is an HTML element.</strong>
# ```
#
# In this element, strong is the name of the tag; the open tag is `<strong>`, and the matching closing tag is `</strong>`. The way you should interpret this is that the text “This is an HTML element” should be “strong”, i.e., typically this will be bold text.
#
# HTML elements can and commonly do nest:
#
# ```html
# <strong>This is strong, and <u>this is underlined and strong.</u></strong>
# ```
#
# In addition to the names, opening tags can contain extra information about the element. These are called attributes:
#
# ```html
# <a href='http://www.google.com'>A link to Google's main page</a>
# ```
#
# In this case, we’re using the `a` element which stood for “anchor”, but now is almost universally used as a “link”. The attribute `href` means “HTML reference”. The meaning given to each attribute changes from element to element.
#
# Other important attributes for our purposes are `id` and `class`. The id attribute gives the attribute a unique identifier, which can then be used to access the element programmatically. Think of it as making the element accessible via a global variable.
#
# The class is similar but is intended to be applied to a whole “class” of elements.
#
# HTML pages require some boilerplate. Here is a minimal page:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title></title>
# </head>
# <body>
# Hello World! What's up?
# </body>
# </html>
# ```
#
# The `<head>` contains meta-information such as the title of the site, the `<body>` contains the actual data.

# %% [markdown]
# ### Hierarchy
#
# Data in HTML is often structured hierarchically:
#
# ```html
# <body>
#   <article>
#     <span class="date">Published: 1969-10-22</span>
#     <span class="author">Led Zeppelin</span>
#     <h1>Ramble On</h1>
#     <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
#   </article>
#   <article>
#     <span class="date">Published: 2016-05-03</span>
#     <span class="author">Radiohead</span>
#     <h1>Burn the Witch</h1>
#     <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>
#   </article>
# </body>
# ```
#
# Here, the title of the song is nested three levels deep: `body > article > h1`.

# %% [markdown]
# ### Tables
#
# Data is also often stored in HTML tables, which are enclosed in a `<table>` tag. `<tr>` indicates a row (table row), `<th>` and `<td>` are used to demark cells, either header cells (`<th>`, table header) or regular cells (`<td>`, table data). Here's an example:
#
# ```html
# <table>
#     <tr>
#         <th></th>
#         <th>The Beatles</th>
#         <th>Led Zeppelin</th>
#     </tr>
#     <tr>
#         <td># Band Members</td>
#         <td>4</td>
#         <td>4</td>
#     </tr>
# </table>
# ```

# %% [markdown]
# ### The DOM
#
# As we have seen above, a markup document looks a lot like a tree: it has a root, the HTML element, and elements can have children that are containing elements themselves.
#
# While HTML is a textual representation of a markup document, the DOM is a programming interface for it. Also the DOM represents the state of a page as it's rendered, that (nowadays) doesn't mean that there is an underlying HTML document that corresponds to that exactly. Rather, the DOM is dynamically generated with, e.g., JavaScript.
#
# In this class we will use “DOM” to mean the tree created by the web browsers to represent the document.
#
# #### Inspecting the DOM in a browser
#
# Perhaps the most important habit when scraping is to investigate the source of a page using the Developer Tools. In this case, we’ll look at the **element tree**, by clicking on the menu bar: View → Developer → Developer Tools.
#
# Alternatively, you can right click on any part of the webpage, and choose “Inspect Element”. Notice that there can be a big difference between what is in the DOM and what is in the source.
#
# Take a look at the DOM of [this html page](lyrics.html). Next, we'll scrape the data from this page!

# %% [markdown]
# # Scraping with BeautifulSoup
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) is a Python library design for computationally extracting data from html documents. It supports navigating in the DOM and retrieving exactly the data elements you need.
#
# Let's start with a simple example using the [lyrics.html](lyrics.html) file.

# %%
from bs4 import BeautifulSoup

# we tell BeautifulSoup and tell it which parser to use
song_soup = BeautifulSoup(open("lyrics.html"), "html.parser")
# the output corresponds exactly to the html file
song_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Lyrics</title>
# </head>
# <body>
# <article id="zep">
# <span class="date">Published: 1969-10-22</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>
# <article id="radio">
# <span class="date">Published: 2016-05-03</span>
# <span class="author">Radiohead</span>
# <h1>Burn the Witch</h1>
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>
# </article>
# </body>
# </html>

# %% [markdown]
# Sometimes, generated (minified) html can be hard to read (not in this case), so we can format it:

# %%
print(song_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Lyrics
#   </title>
#  </head>
#  <body>
#   <article id="zep">
#    <span class="date">
#     Published: 1969-10-22
#    </span>
#    <span class="author">
#     Led Zeppelin
#    </span>
#    <h1>
#     Ramble On
#    </h1>
#    <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#    </div>
#   </article>
#   <article id="radio">
#    <span class="date">
#     Published: 2016-05-03
#    </span>
#    <span class="author">
#     Radiohead
#    </span>
#    <h1>
#     Burn the Witch
#    </h1>
#    <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#    </div>
#   </article>
#  </body>
# </html>

# %% [markdown]
# We can access content by tags:

# %%
# get the title tag
song_soup.title
# Out:
# <title>Lyrics</title>

# %% [markdown]
# And get the text out of the tag:

# %%
song_soup.title.string
# Out:
# 'Lyrics'

# %% [markdown]
# Directly accessing an element works for the first occurence of a tag, we don't get the others.

# %%
song_soup.div
# Out:
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>

# %% [markdown]
# Again, we can retreive the text content of an element:

# %%
print(song_soup.div.string)
# Out:
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can use attributes to find a specific element:

# %%
song_soup.find(id="zep")
# Out:
# <article id="zep">
# <span class="date">Published: 1969-10-22</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>

# %% [markdown]
#  We can also get only the text, not the html markup with [`find()`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find):

# %%
text = song_soup.find(id="zep").get_text()
print(text)
# Out:
# Published: 1969-10-22
# Led Zeppelin
# Ramble On
#
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can also use [`find_all()`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#calling-a-tag-is-like-calling-find-all) to get all instances of a tag:

# %%
h1s = song_soup.find_all("h1")
h1s
# Out:
# [<h1>Ramble On</h1>, <h1>Burn the Witch</h1>]

# %% [markdown]
# This returns a list of beautiful soup elements:

# %%
type(h1s[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# It's easy to get the text out of this:

# %%
string_h1s = [tag.get_text() for tag in h1s]
string_h1s
# Out:
# ['Ramble On', 'Burn the Witch']

# %% [markdown]
# We can also find elements by ID:

# %%
song_soup.find_all(id="zep")
# Out:
# [<article id="zep">
#  <span class="date">Published: 1969-10-22</span>
#  <span class="author">Led Zeppelin</span>
#  <h1>Ramble On</h1>
#  <div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>
#  </article>]

# %% [markdown]
# Or by class (notice the keyword here is `class_` because the word `class` is reserved in Python.

# %%
song_soup.find_all(class_="content")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>,
#  <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# Since `find_all` is so commonly used, you can use a shortcut by just calling directly on an object:

# %%
song_soup("div")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>,
#  <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# We can address the elements in the returned object directly:

# %%
song_soup("div")[1]
# Out:
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# Or iterate over it:

# %%
for p in song_soup.find_all("div"):
    print("---")
    print(p)
# Out:
# ---
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# ---
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# ### CSS Selectors
#
# We can also use CSS selectors. CSS Selectors apply, among others, to elements, classes, and IDs.
#
# Below is an example of how CSS is used to style different elements.
#
#
# ```CSS
# /* Element Selector */
# article {
#   color: FireBrick;
# }
#
# /* ID selector */
# #myID {
#   color: Tomato;
# }
#
# /* Class selector */
# .myClass {
#   color: Aquamarine;
# }
#
# /* Child selector. Only DIRECT children match */
# p > b {
#   color: SteelBlue;
# }
#
# /* Descendant selector. Every time a b is nested within a div this matches */
# div b {
#   color: green;
# }
#
# ```
#
# [Here is an example](https://jsfiddle.net/gxhqv26m/1/) with all the important selectors.
#
# Let's try this in Python:

# %%
# selecting all elements of class .content
song_soup.select(".content")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>,
#  <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %%
# selecting all divs that are somewhere below the id radio in the tree
song_soup.select("#radio div")
# Out:
# [<div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# OK, now we know how to extract information out of a website. Let's look at a complete example.

# %% [markdown]
# ## Fetching a Website
#
# Downloading websites is easy and very efficient. It turns out, that you can cause quite a high load on a server when you scrape it. To avoid that, webmasters usually publish what kinds of scraping they allow on their websites. You should check out a website's terms of service and the `robots.txt` of a domain before crawling excessively. Terms of service are usually broad, so searching for “scraping” or “crawling” is a good idea.
#
# Let's take a look at [Google Scholar's robots.txt](https://scholar.google.com/robots.txt):
#
# ```
# User-agent: *
# Disallow: /search
# Allow: /search/about
# Disallow: /sdch
# Disallow: /groups
# Disallow: /index.html?
# Disallow: /?
# Allow: /?hl=
# ...
# Disallow: /scholar
# Disallow: /citations?
# ...
# ```
#
# Here it specifies that you're not allowed to crawl a lot of the pages. The `/scholar` subdirectory is especially painful because it prohibits you from generating queries dynamically.
#
# It's also common that sites ask you to delay crawiling:
#
# ```
# Crawl-delay: 30
# Request-rate: 1/30
# ```
#
# You should respect those restrictions. Now, no one can stop you from running a request through a crawler, but sites like google scholar will block you VERY quickly if you request to many pages in a short time-frame. It's also common that bigger sites serve up a CAPTCHA if they think you're using a bot to crawl.
#
# An alternative strategy to dynamically accessing the site you're crawling (as we're doing in the next example) is to download a local copy of the website and crawl that. This ensures that you hit the site only once per page. A good tool to achieve that is [wget](https://www.gnu.org/software/wget/).

# %% [markdown]
# ### Example: Utah's course enrollments
#
# We're going to build a dataset of classes offered this fall at the U and look at the enrollment numbers. We'll use the catalog listed here:
# https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/index.html
#
# The U doesn't seem to care whether/how we crawl the websites, the [fineprint](https://www.utah.edu/disclaimer/) doesn't mention it and neither does the `robots.txt`: http://www.utah.edu/robots.txt
#
# We'll use the [`urllib.request`](https://docs.python.org/3.0/library/urllib.request.html) library to retreive the websites.

# %%
import urllib.request
url = "https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/"
# here we actually access the website
with urllib.request.urlopen(url) as response:
    html = response.read()
    html = html.decode('utf-8')

# save the file
with open('class_schedule.html', 'w') as new_file:
    new_file.write(html)

# here it's already a local operation
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Let's take a look at the first 5000 lines of this page:

# %%
print(soup.prettify()[0:5000])
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedules
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans+Condensed:300,300i,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/main.css" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/addins.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/tablesaw/3.1.2/tablesaw.css" integrity="sha256-RKWkj+/VPTTBpmJvgbTZhLSjgt7/i5qqwdo6uULEVT4=" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/png"/>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" rel="stylesheet"/>
#   <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet">
#    <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
#    <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-VazP97ZCwtekAsvgPBSUwPFKdrwD3unUfSGVYrahUqU=" src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-qHxZMNbjFuNl2oF62psx7AbJQHq4oEXXw4DLk3ehJrg=" src="https://cdnjs.cloudflare.com/ajax/libs/tablesaw/3.1.2/tablesaw.jquery.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-joTU9SuZXYDU3Jusrd8y9btQigslF8FKO69YRTzqVhY=" src="https://cdnjs.cloudflare.com/ajax/libs/tablesaw/3.1.2/tablesaw-init.js">
#    </script>
#    <script async="" id="UA-58881890-50" src="https://ssl.google-analytics.com/analytics.js">
#    </script>
#    <script src="/uofu/stu/ClassSchedules/scripts/elevator.min.js">
#    </script>
#    <script src="/uofu/stu/ClassSchedules/scripts/addins.js">
#    </script>
#    <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js">
#    </script>
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   </link>
#  </head>
#  <body class="d-flex flex-column bg-light">
#   <!--*** START OF HEADER ***-->
#   <header class="bg-primary pt-3 pb-2 px-4 px-sm-5" role="banner">
#    <div class="container-fluid">
#     <a class="skip sr-only sr-only-focusable bg-white" href="#uu-skip-target">
#      Skip to Main Content
#     </a>
#     <div class="row">
#      <div class="col-xs-2 align-self-center">
#       <a href="//utah.edu" target="_blank">
#        <img alt="The University of Utah" class="logo" src="//templates.utah.edu/apps/v1/_images/logo/ulogo.png"/>
#       </a>
#      </div>
#      <div class="col-xs-10 align-self-center">
#       <h1 class="logo-text display-3 text-white p-1 mb-0">
#        University of Utah
#       </h1>
#      </div>
#     </div>
#    </div>
#   </header>
#   <!--*** END OF HEADER ***-->
#   <!--*** START OF NAVIGATION ***-->
#   <nav class="bg-secondary py-0 px-4 px-sm-5 navbar navbar-expand-lg navbar-dark" role="navigation">
#    <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler border-0" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#     <span class="navbar-toggler-icon">
#     </span>
#    </button>
#    <div class="collapse navbar-collapse" id="navbarSupportedContent">
#     <ul class="navbar-nav mr-auto text-nowrap">
#      <!-- Use nav-iem--left-align only for the first button -->
#      <li class="nav-item nav-item--left-align">
#       <a class="nav-link" href="index.html">
#        Home
#       </a>
#      </li>
#      <li class="nav-item dropdown">
#       <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#        Terms
#       </a>
#       <div aria-labelledby="navbarDropdown" class="dropdown-menu">
#        <a class="dropdown-item" href="/uofu/stu/ClassSchedules/main/1236/index.html">
#         Summer 2023
#        </a>
#        <a class="dropdown-item" href="/uofu/stu/ClassSchedules/main/1234/index.html">
#         Spring 2023
#        </a>
#        <a class="dropdown-item" href="/uofu/stu/ClassSchedules/main/1228/index.html">
#         Fall 2

# %% [markdown]
# What we want to get out of this page is the link to the subject specific subject course lists.
#
# While you could find this in the text output in python, it's much easier to find the relevant parts in your browser's built in inspector. Here, we've highlighted one of the subjects (Accounting):
#
# ![Chrome Inspector](inspector.png)

# %% [markdown]
# This is the relevant HTML snippet:
#
# ```html
# <div class="col-lg-2 p-1">
#     <a class="btn btn-light btn-block" href="class_list.html?subject=ACCTG">ACCTG - Accounting</a>
# </div>
# ```
#
# We can scrape this based on the combination of an `<a>` element ant the `btn-block` class attribute.
#
# Let's build a dictionary of subject shorthands to a tuple of the full subject name and links to the relevant courses. For CS this should look like this:
#
# ```
# CS: (Computer Science, https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1214/class_list.html?subject=CS)
# ```

# %%
subjects = {}

# use the select statement with element.class syntax to retrieve the relevant subjects
for subject in soup.select("a.btn-block"):
    # get the link out of the href attribute
    link_tail = subject.get("href")
    # concatenate the base URL and the tail of the link
    link = url + link_tail
    # the subject shortname is embedded within the <a> tag, we split by a dash and spaces
    subject_text = subject.get_text().split(" - ")
    # write it to the dictionary
    subjects[subject_text[0]] = (subject_text[1], link)

subjects
# Out:
# {'ACCTG': ('Accounting',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ACCTG'),
#  'AEROS': ('Aerospace Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=AEROS'),
#  'ANAT': ('Neurobiology and Anatomy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ANAT'),
#  'ANES': ('Anesthesiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ANES'),
#  'ANTH': ('Anthropology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ANTH'),
#  'ARAB': ('Arabic',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ARAB'),
#  'ARCH': ('Architecture',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ARCH'),
#  'ART': ('Art',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ART'),
#  'ARTH': ('Art History',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ARTH'),
#  'ARTX': ('Arts Technology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ARTX'),
#  'ASL': ('American Sign Language',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ASL'),
#  'ASTP': ('Asian Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ASTP'),
#  'ASTR': ('Astronomy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ASTR'),
#  'ATHL': ('Athletics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ATHL'),
#  'ATMOS': ('Atmospheric Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ATMOS'),
#  'ATSM': ('Athletic Training and Sports Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ATSM'),
#  'BALLE': ('Ballet',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BALLE'),
#  'BART': ('Book Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BART'),
#  'BCOR': ('Business Core',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BCOR'),
#  'BENN': ('Bennion Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BENN'),
#  'BIO C': ('Biochemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BIO%20C'),
#  'BIOL': ('Biology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BIOL'),
#  'BLCHM': ('Biological Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BLCHM'),
#  'BME': ('Biomedical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BME'),
#  'BMI': ('Biomedical Informatics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BMI'),
#  'BUS': ('Business',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=BUS'),
#  'CECRT': ('CE Certificate',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CECRT'),
#  'CERM': ('Ceramics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CERM'),
#  'CH EN': ('Chemical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CH%20EN'),
#  'CHEM': ('Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CHEM'),
#  'CHIN': ('Chinese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CHIN'),
#  'CL CV': ('Classical Civilization',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CL%20CV'),
#  'CLCS': ('Comparative Literary and Cultural Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CLCS'),
#  'CMP': ('City & Metropolitan Planning',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CMP'),
#  'COMM': ('Communication',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=COMM'),
#  'COMP': ('Computing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=COMP'),
#  'CRIM': ('Criminology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CRIM'),
#  'CS': ('Computer Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CS'),
#  'CSD': ('Communication Sciences and Disorders',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CSD'),
#  'CTLE': ('Center for Teaching Excellence',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CTLE'),
#  'CVEEN': ('Civil and Environmental Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CVEEN'),
#  'CVP': ('Cardiovascular Perfusion',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=CVP'),
#  'DANC': ('Modern Dance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DANC'),
#  'DENT': ('Dentistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DENT'),
#  'DERM': ('Dermatology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DERM'),
#  'DES': ('Design',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DES'),
#  'DESGR': ('Graphic Design',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DESGR'),
#  'DISAB': ('Disability Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DISAB'),
#  'DRAW': ('Drawing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DRAW'),
#  'DS': ('Data Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=DS'),
#  'EAE': ('Entertainment Arts & Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=EAE'),
#  'ECE': ('Electrical and Computer Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ECE'),
#  'ECON': ('Economics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ECON'),
#  'ECS': ('Education, Culture and Society',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ECS'),
#  'ED PS': ('Educational Psychology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ED%20PS'),
#  'EDU': ('Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=EDU'),
#  'EHUM': ('Environmental Humanities',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=EHUM'),
#  'ELI': ('English Language Institute',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ELI'),
#  'ELP': ('Educational Leadership & Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ELP'),
#  'ENGIN': ('Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ENGIN'),
#  'ENGL': ('English',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ENGL'),
#  'ENTP': ('Entrepreneurship',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ENTP'),
#  'ENVST': ('Environmental and Sustainability Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ENVST'),
#  'ESSF': ('ESS Fitness Courses',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ESSF'),
#  'ETHNC': ('Ethnic Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ETHNC'),
#  'FA': ('Fine Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=FA'),
#  'FCS': ('Family and Consumer Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=FCS'),
#  'FILM': ('Film and Media Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=FILM'),
#  'FINAN': ('Finance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=FINAN'),
#  'FP MD': ('Family and Preventive Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=FP%20MD'),
#  'FRNCH': ('French',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=FRNCH'),
#  'GEO': ('Geology and Geophysics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=GEO'),
#  'GEOG': ('Geography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=GEOG'),
#  'GERM': ('German',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=GERM'),
#  'GERON': ('Gerontology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=GERON'),
#  'GNDR': ('Gender Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=GNDR'),
#  'GREEK': ('Greek',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=GREEK'),
#  'H EDU': ('Health Promotion & Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=H%20EDU'),
#  'H GEN': ('Human Genetics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=H%20GEN'),
#  'HINDI': ('Hindi',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HINDI'),
#  'HIST': ('History',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HIST'),
#  'HKR': ('Health, Kinesiology, and Recreation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HKR'),
#  'HLTH': ('Health',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HLTH'),
#  'HNKLY': ('Hinckley Institute',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HNKLY'),
#  'HONOR': ('Honors College',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HONOR'),
#  'HSP': ('Health, Society and Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HSP'),
#  'HUM': ('Humanities',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=HUM'),
#  'IAGE': ('International Affairs and Global Enterprise',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=IAGE'),
#  'INTL': ('International Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=INTL'),
#  'INTMD': ('Internal Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=INTMD'),
#  'IS': ('Information Systems',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=IS'),
#  'ITAL': ('Italian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ITAL'),
#  'JAPAN': ('Japanese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=JAPAN'),
#  'KINES': ('Kinesiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=KINES'),
#  'KOREA': ('Korean',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=KOREA'),
#  'LAS': ('Latin American Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LAS'),
#  'LATIN': ('Latin',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LATIN'),
#  'LAW': ('Law',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LAW'),
#  'LAWC': ('Law Noncredit Certificate',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LAWC'),
#  'LDRSP': ('Leadership',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LDRSP'),
#  'LEAP': ('LEAP Program',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LEAP'),
#  'LING': ('Linguistics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LING'),
#  'LLART': ('Art and Photography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLART'),
#  'LLBUS': ('Business and Finance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLBUS'),
#  'LLCFT': ('Crafts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLCFT'),
#  'LLFW': ('Food and Wine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLFW'),
#  'LLHG': ('Home and Garden',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLHG'),
#  'LLHL': ('Healthy Living',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLHL'),
#  'LLLAN': ('Language',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLLAN'),
#  'LLMT': ('Music and Theatre',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLMT'),
#  'LLPOT': ('Potpourri',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLPOT'),
#  'LLREC': ('Recreation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLREC'),
#  'LLWRC': ('Writing/Creative',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=LLWRC'),
#  'MATH': ('Mathematics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MATH'),
#  'MBIOL': ('Molecular Biology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MBIOL'),
#  'MD CH': ('Pharmacy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MD%20CH'),
#  'MD ID': ('Interdepartmental Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MD%20ID'),
#  'MD LB': ('Medical Laboratory Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MD%20LB'),
#  'MDCRC': ('Clinical Research Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MDCRC'),
#  'ME EN': ('Mechanical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ME%20EN'),
#  'MET E': ('Metallurgical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MET%20E'),
#  'MG EN': ('Mining Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MG%20EN'),
#  'MGT': ('Management',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MGT'),
#  'MHA': ('Master Healthcare Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MHA'),
#  'MID E': ('Middle East Language and Area Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MID%20E'),
#  'MIL S': ('Military Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MIL%20S'),
#  'MKTG': ('Marketing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MKTG'),
#  'MSE': ('Materials Science and Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MSE'),
#  'MST': ('Master of Science and Technology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MST'),
#  'MUSC': ('Music',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MUSC'),
#  'NAHTL': ('Nahuatl',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NAHTL'),
#  'NAVJO': ('Navajo',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NAVJO'),
#  'NEURO': ('Neurology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NEURO'),
#  'NEUSC': ('Neuroscience',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NEUSC'),
#  'NSURG': ('Neurosurgery',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NSURG'),
#  'NUCL': ('Nuclear Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NUCL'),
#  'NUIP': ('Nutrition and Integrative Physiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NUIP'),
#  'NURS': ('Nursing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NURS'),
#  'NV SC': ('Naval Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=NV%20SC'),
#  'OBST': ('Obstetrics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=OBST'),
#  'OC TH': ('Occupational Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=OC%20TH'),
#  'OEHS': ('Occupational and Environmental Health',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=OEHS'),
#  'ONCSC': ('Oncological Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ONCSC'),
#  'OPHTH': ('Ophthalmology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=OPHTH'),
#  'ORTHO': ('Orthopedics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=ORTHO'),
#  'OSC': ('Operations and Supply Chain',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=OSC'),
#  'OSHER': ('Osher Lifelong Learning',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=OSHER'),
#  'PADMN': ('Public Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PADMN'),
#  'PAS': ('Physician Assistant Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PAS'),
#  'PATH': ('Pathology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PATH'),
#  'PBHLT': ('Public Health',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PBHLT'),
#  'PCS': ('Peace and Conflict Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PCS'),
#  'PCTH': ('Pharmacotherapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PCTH'),
#  'PED': ('Pediatrics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PED'),
#  'PERS': ('Persian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PERS'),
#  'PH MD': ('Phys Med & Rehabilitation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PH%20MD'),
#  'PH TH': ('Physical Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PH%20TH'),
#  'PH TX': ('Pharmacology and Toxicology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PH%20TX'),
#  'PHARM': ('Pharmacy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHARM'),
#  'PHCEU': ('Molecular Pharmaceutics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHCEU'),
#  'PHIL': ('Philosophy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHIL'),
#  'PHOTO': ('Digital Photography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHOTO'),
#  'PHS': ('Population Health Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHS'),
#  'PHYS': ('Physics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHYS'),
#  'PHYSL': ('Physiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PHYSL'),
#  'POLS': ('Political Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=POLS'),
#  'PREP': ('Preparatory',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PREP'),
#  'PRINT': ('Printmaking',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PRINT'),
#  'PROEA': ('Professional Education Academies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PROEA'),
#  'PROED': ('Professional Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PROED'),
#  'PRT': ('Parks, Recreation and Tourism',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PRT'),
#  'PRTL': ('PRT Outdoor Adventure',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PRTL'),
#  'PRTS': ('PRT Outdoor Adventure',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PRTS'),
#  'PRTW': ('PRT Outdoor Adventure',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PRTW'),
#  'PSY': ('Psychology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PSY'),
#  'PSYCT': ('Psychiatry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PSYCT'),
#  'PTGSE': ('Portuguese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PTGSE'),
#  'PUBPL': ('Public Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=PUBPL'),
#  'QAMO': ('Quantitative Analysis of Markets and Organizations',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=QAMO'),
#  'QUECH': ('Quechua',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=QUECH'),
#  'RDLGY': ('Radiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=RDLGY'),
#  'RDONC': ('Radiation Oncology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=RDONC'),
#  'RECTH': ('Recreational Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=RECTH'),
#  'REDEV': ('Real Estate Development',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=REDEV'),
#  'RELS': ('Religious Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=RELS'),
#  'RHSCI': ('Rehabilitation Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=RHSCI'),
#  'RUSS': ('Russian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=RUSS'),
#  'SAMOA': ('Samoan',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SAMOA'),
#  'SBS': ('Social and Behavioral Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SBS'),
#  'SCI': ('Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SCI'),
#  'SCLPT': ('Sculpture/Intermedia',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SCLPT'),
#  'SOC': ('Sociology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SOC'),
#  'SP ED': ('Special Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SP%20ED'),
#  'SPAN': ('Spanish',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SPAN'),
#  'SR EL': ('Senior Electives',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SR%20EL'),
#  'STAT': ('Statistics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=STAT'),
#  'STRAT': ('Strategy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=STRAT'),
#  'SURG': ('Surgery',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SURG'),
#  'SUST': ('Sustainability',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SUST'),
#  'SW': ('Social Work',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=SW'),
#  'THEA': ('Theatre',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=THEA'),
#  'UGS': ('Undergraduate Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=UGS'),
#  'UUHED': ('MEd in Health Professions',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=UUHED'),
#  'UUHSC': ('Health Sciences Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=UUHSC'),
#  'VIET': ('Vietnamese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=VIET'),
#  'WLC': ('World Languages and Cultures',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=WLC'),
#  'WRTG': ('Writing and Rhetoric Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=WRTG'),
#  'YEHS': ('High School',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=YEHS')}

# %% [markdown]
# Let's look at the entry for math:

# %%
subjects["MATH"]
# Out:
# ('Mathematics',
#  'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/class_list.html?subject=MATH')

# %% [markdown]
# That's what we want.
#
# As an aside: we could have taken a different approach here. Note how the URL has a deterministic query parameter that matches the subject:
#
# ```
# class_list.html?subject=MATH
# ```
#
# We could use this to also retrieve the links if we only had the subject shortnames.

# %% [markdown]
# #### Getting a list of classes
#
# Next, it's time to get the courses. Let's look at the [website for CS](https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1204/class_list.html?subject=CS).
#
# We'll fetch this class list in a function where we pass in the subject name:

# %%
def getWebsiteAsSoup(url):
    """ 
    Retrieve a website and return it as a BeautifulSoup object.   
    """
    
    req = urllib.request.Request(url)
    with urllib.request.urlopen(req) as response:
        classlist_html = response.read()
    
    class_soup = BeautifulSoup(classlist_html, 'html.parser')
    with open('class_list.html', 'w') as new_file:
        new_file.write(str(class_soup))
        
    return class_soup

# %% [markdown]
# Let's run this function for CS and look at the output:

# %%
class_soup = getWebsiteAsSoup(subjects["CS"][1])

# %%
print(class_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedule
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans+Condensed:300,300i,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/main.css" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/addins.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/tablesaw/3.1.2/tablesaw.css" integrity="sha256-RKWkj+/VPTTBpmJvgbTZhLSjgt7/i5qqwdo6uULEVT4=" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/png"/>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" rel="stylesheet"/>
#   <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet">
#    <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
#    <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-VazP97ZCwtekAsvgPBSUwPFKdrwD3unUfSGVYrahUqU=" src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-qHxZMNbjFuNl2oF62psx7AbJQHq4oEXXw4DLk3ehJrg=" src="https://cdnjs.cloudflare.com/ajax/libs/tablesaw/3.1.2/tablesaw.jquery.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-joTU9SuZXYDU3Jusrd8y9btQigslF8FKO69YRTzqVhY=" src="https://cdnjs.cloudflare.com/ajax/libs/tablesaw/3.1.2/tablesaw-init.js">
#    </script>
#    <script async="" id="UA-58881890-50" src="https://ssl.google-analytics.com/analytics.js">
#    </script>
#    <script src="/uofu/stu/ClassSchedules/scripts/elevator.min.js">
#    </script>
#    <script src="/uofu/stu/ClassSchedules/scripts/addins.js">
#    </script>
#    <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js">
#    </script>
#    <meta charset="utf-8"/>
#   </link>
#  </head>
#  <body class="d-flex flex-column bg-light">
#   <!--*** START OF HEADER ***-->
#   <header class="bg-primary pt-3 pb-2 px-4 px-sm-5" role="banner">
#    <div class="container-fluid">
#     <a class="skip sr-only sr-only-focusable bg-white" href="#uu-skip-target">
#      Skip to Main Content
#     </a>
#     <div class="row">
#      <div class="col-xs-2 align-self-center">
#       <a href="//utah.edu" target="_blank">
#        <img alt="The University of Utah" class="logo" src="//templates.utah.edu/apps/v1/_images/logo/ulogo.png"/>
#       </a>
#      </div>
#      <div class="col-xs-10 align-self-center">
#       <h1 class="logo-text display-3 text-white p-1 mb-0">
#        University of Utah
#       </h1>
#      </div>
#     </div>
#    </div>
#   </header>
#   <!--*** END OF HEADER ***-->
#   <!--*** START OF NAVIGATION ***-->
#   <nav class="bg-secondary py-0 px-4 px-sm-5 navbar navbar-expand-lg navbar-dark" role="navigation">
#    <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler border-0" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#     <span class="navbar-toggler-icon">
#     </span>
#    </button>
#    <div class="collapse navbar-collapse" id="navbarSupportedContent">
#     <ul class="navbar-nav mr-auto text-nowrap">
#      <!-- Use nav-iem--left-align only for the first button -->
#      <li class="nav-item nav-item--left-align">
#       <a class="nav-link" href="index.html">
#        Home
#       </a>
#      </li>
#      <li class="nav-item dropdown">
#       <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#        Terms
#       </a>
#       <div aria-labelledby="navbarDropdown" class="dropdown-menu">
#        <a class="dropdown-item" href="/uofu/stu/ClassSchedules/main/1236/index.html">
#         Summer 2023
#        </a>
#        <a class="dropdown-item" href="/uofu/stu/ClassSchedules/main/1234/index.html">
#         Spring 2023
#        </a>
#        <a class="dropdown-item" href="/uofu/stu/ClassSchedules/main/1228/index.html">
#         Fall 2022
#        </a>
#       </div>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="//registrar.utah.edu/register/schedule-builder.php" target="_blank">
#        Schedule Builder
#       </a>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="//registrar.utah.edu/handbook/" target="_blank">
#        Student Handbook
#       </a>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="//catalog.utah.edu/" target="_blank">
#        General Catalog
#       </a>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="//registrar.utah.edu/academic-calendars/spring2023.php" target="_blank">
#        Academic Calendar
#       </a>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="http://www.bookstore.utah.edu/UTAH/SelectTermDept.aspx" target="_blank">
#        Find Textbooks
#       </a>
#      </li>
#      <li class="nav-item">
#       <a class="nav-link" href="https://ctle.utah.edu/scf/reports/student" target="_blank">
#        View Course Feedback
#       </a>
#      </li>
#     </ul>
#    </div>
#    <ul class="navbar-nav text-light">
#     <li class="nav-item dropdown">
#     </li>
#    </ul>
#   </nav>
#   <!--*** END OF NAVIGATION ***-->
#   <div class="container-fluid mb-auto mt-0 mx-0 p-0">
#    <div class="row">
#     <div class="col">
#      <div class="container-fluid px-2 px-sm-4 px-md-5 mt-2">
#       <div class="row align-items-center">
#        <div class="col-lg-8">
#         <section>
#          <h1>
#           <b>
#            <span>
#             Computer Science
#            </span>
#            -
#            <span>
#             Main Campus
#            </span>
#           </b>
#           <span>
#            - Spring 2023 Class Schedule
#           </span>
#          </h1>
#          <h2>
#          </h2>
#         </section>
#        </div>
#        <div class="col-lg-3 offset-lg-1">
#         <div class="subject-info">
#          <section>
#           <ul class="list-group mt-3">
#            <li class="list-group-item">
#             Location: MEB 3190
#            </li>
#            <li class="list-group-item">
#             Phone: 801-581-8224
#            </li>
#           </ul>
#          </section>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!--*** CONTENT *** -->
#    <section class="container-fluid px-2 px-sm-4 px-md-5 flex-grow-1">
#     <div class="row">
#      <div class="col-12 col-sm-12 col-md-6 col-lg-4 col-xl-3">
#       <div class="mt-3">
#        <button class="btn btn-sm btn-outline-dark btn-block" id="filter-show-hide">
#         <i class="fas fa-angle-up">
#         </i>
#         <span>
#          Hide Search &amp; Filters
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="row">
#      <div class="collapse show col-12 col-sm-12 col-md-6 col-lg-4 col-xl-3" id="filter-controls">
#       <div class="row">
#        <div class="col">
#         <div class="card mt-3">
#          <div class="card-body bg-search">
#           <form action="search.html" method="post">
#            <div class="form-group">
#             <h2>
#              <label for="search">
#               Search for a Class
#              </label>
#             </h2>
#             <input class="form-control" id="search" name="searchString" placeholder="Search Code and/or Catalog Number" type="text" value=" "/>
#            </div>
#            <button class="btn btn-block btn-primary" type="submit">
#             Search
#            </button>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col">
#         <div class="card mt-3">
#          <div class="card-body">
#           <div class="list-group list-group-flush">
#            <!-- Filter by Subject -->
#            <!-- Filter by Classes -->
#            <div class="pb-2">
#             <div class="row justify-content-between flex-nowrap">
#              <div class="col-8">
#               <h2>
#                Filter Classes
#               </h2>
#              </div>
#              <div class="col">
#               <button class="float-right float-top btn btn-sm btn-outline-dark mr-1" id="filter-reset">
#                Clear
#               </button>
#              </div>
#             </div>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-days">
#             Day
#            </a>
#            <div class="collapse" id="filter-days">
#             <fieldset>
#              <legend>
#               Select days:
#              </legend>
#              <label class="btn btn-light btn-sm">
#               Mo
#               <input autocomplete="off" data-search-query="Mo" data-search-type="day" type="checkbox" value="">
#               </input>
#              </label>
#              <label class="btn btn-light btn-sm">
#               Tu
#               <input autocomplete="off" data-search-query="Tu" data-search-type="day" type="checkbox" value=""/>
#              </label>
#              <label class="btn btn-light btn-sm">
#               We
#               <input autocomplete="off" data-search-query="We" data-search-type="day" type="checkbox" value=""/>
#              </label>
#              <label class="btn btn-light btn-sm">
#               Th
#               <input autocomplete="off" data-search-query="Th" data-search-type="day" type="checkbox" value=""/>
#              </label>
#              <label class="btn btn-light btn-sm">
#               Fr
#               <input autocomplete="off" data-search-query="Fr" data-search-type="day" type="checkbox" value=""/>
#              </label>
#              <label class="btn btn-light btn-sm">
#               Sa
#               <input autocomplete="off" data-search-query="Sa" data-search-type="day" type="checkbox" value=""/>
#              </label>
#              <label class="btn btn-light btn-sm">
#               Su
#               <input autocomplete="off" data-search-query="Su" data-search-type="day" type="checkbox" value=""/>
#              </label>
#             </fieldset>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-times">
#             Time
#            </a>
#            <div class="collapse" id="filter-times">
#             <label class="btn btn-light btn-sm mr-1">
#              Morning
#              <input autocomplete="off" data-search-query="M" data-search-type="time" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              Afternoon
#              <input autocomplete="off" data-search-query="A" data-search-type="time" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              Evening
#              <input autocomplete="off" data-search-query="E" data-search-type="time" type="checkbox" value=""/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-off-campus">
#             Off Campus
#            </a>
#            <div class="collapse" id="filter-off-campus">
#             <label class="btn btn-light btn-sm">
#              Sandy
#              <input autocomplete="off" data-search-query="SANDY" data-search-type="building-code" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm">
#              St. George
#              <input autocomplete="off" data-search-query="ST. GEORGE" data-search-type="building-code" type="checkbox" value=""/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-attributes">
#             Gen Ed &amp; Bachelor Degree Courses
#            </a>
#            <div class="collapse" id="filter-attributes">
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               AI
#              </span>
#              <input autocomplete="off" data-search-query="AI" data-search-type="req" type="checkbox" value="AI"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               AS
#              </span>
#              <input autocomplete="off" data-search-query="AS" data-search-type="req" type="checkbox" value="AS"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               BF
#              </span>
#              <input autocomplete="off" data-search-query="BF" data-search-type="req" type="checkbox" value="BF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               CW
#              </span>
#              <input autocomplete="off" data-search-query="CW" data-search-type="req" type="checkbox" value="CW"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               DV
#              </span>
#              <input autocomplete="off" data-search-query="DV" data-search-type="req" type="checkbox" value="DV"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               FF
#              </span>
#              <input autocomplete="off" data-search-query="FF" data-search-type="req" type="checkbox" value="FF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               HF
#              </span>
#              <input autocomplete="off" data-search-query="HF" data-search-type="req" type="checkbox" value="HF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               IR
#              </span>
#              <input autocomplete="off" data-search-query="IR" data-search-type="req" type="checkbox" value="IR"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               LR
#              </span>
#              <input autocomplete="off" data-search-query="LR" data-search-type="req" type="checkbox" value="LR"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QA
#              </span>
#              <input autocomplete="off" data-search-query="QA" data-search-type="req" type="checkbox" value="QA"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QB
#              </span>
#              <input autocomplete="off" data-search-query="QB" data-search-type="req" type="checkbox" value="QB"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QI
#              </span>
#              <input autocomplete="off" data-search-query="QI" data-search-type="req" type="checkbox" value="QI"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QR
#              </span>
#              <input autocomplete="off" data-search-query="QR" data-search-type="req" type="checkbox" value="QR"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               SF
#              </span>
#              <input autocomplete="off" data-search-query="SF" data-search-type="req" type="checkbox" value="SF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               WR1
#              </span>
#              <input autocomplete="off" data-search-query="WR1" data-search-type="req" type="checkbox" value="WR1"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               WR2
#              </span>
#              <input autocomplete="off" data-search-query="WR2" data-search-type="req" type="checkbox" value="WR2"/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-multi">
#             Multiple Gen Ed and/or Bachelor degree requirement codes
#            </a>
#            <div class="collapse" id="filter-multi">
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               BFAS
#              </span>
#              <input autocomplete="off" data-search-query="BFAS" data-search-type="req" type="checkbox" value="BFAS"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               BFHF
#              </span>
#              <input autocomplete="off" data-search-query="BFHF" data-search-type="req" type="checkbox" value="BFHF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               CWDV
#              </span>
#              <input autocomplete="off" data-search-query="CWDV" data-search-type="req" type="checkbox" value="CWDV"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               CWHF
#              </span>
#              <input autocomplete="off" data-search-query="CWHF" data-search-type="req" type="checkbox" value="CWHF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               CWIR
#              </span>
#              <input autocomplete="off" data-search-query="CWIR" data-search-type="req" type="checkbox" value="CWIR"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               DVBF
#              </span>
#              <input autocomplete="off" data-search-query="DVBF" data-search-type="req" type="checkbox" value="DVBF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               DVFF
#              </span>
#              <input autocomplete="off" data-search-query="DVFF" data-search-type="req" type="checkbox" value="DVFF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               DVHF
#              </span>
#              <input autocomplete="off" data-search-query="DVHF" data-search-type="req" type="checkbox" value="DVHF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               DVSF
#              </span>
#              <input autocomplete="off" data-search-query="DVSF" data-search-type="req" type="checkbox" value="DVSF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               FFHF
#              </span>
#              <input autocomplete="off" data-search-query="FFHF" data-search-type="req" type="checkbox" value="FFHF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               IRBF
#              </span>
#              <input autocomplete="off" data-search-query="IRBF" data-search-type="req" type="checkbox" value="IRBF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               IRFF
#              </span>
#              <input autocomplete="off" data-search-query="IRFF" data-search-type="req" type="checkbox" value="IRFF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               IRHF
#              </span>
#              <input autocomplete="off" data-search-query="IRHF" data-search-type="req" type="checkbox" value="IRHF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               IRSF
#              </span>
#              <input autocomplete="off" data-search-query="IRSF" data-search-type="req" type="checkbox" value="IRSF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QBBF
#              </span>
#              <input autocomplete="off" data-search-query="QBBF" data-search-type="req" type="checkbox" value="QBBF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QBCW
#              </span>
#              <input autocomplete="off" data-search-query="QBCW" data-search-type="req" type="checkbox" value="QBCW"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QBHF
#              </span>
#              <input autocomplete="off" data-search-query="QBHF" data-search-type="req" type="checkbox" value="QBHF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QBQI
#              </span>
#              <input autocomplete="off" data-search-query="QBQI" data-search-type="req" type="checkbox" value="QBQI"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QIBF
#              </span>
#              <input autocomplete="off" data-search-query="QIBF" data-search-type="req" type="checkbox" value="QIBF"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QICW
#              </span>
#              <input autocomplete="off" data-search-query="QICW" data-search-type="req" type="checkbox" value="QICW"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QIIR
#              </span>
#              <input autocomplete="off" data-search-query="QIIR" data-search-type="req" type="checkbox" value="QIIR"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               QRQI
#              </span>
#              <input autocomplete="off" data-search-query="QRQI" data-search-type="req" type="checkbox" value="QRQI"/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-continuing-ed">
#             Continuing Education
#            </a>
#            <div class="collapse" id="filter-continuing-ed">
#             <label class="btn btn-light btn-sm mr-1">
#              AOCE
#              <input autocomplete="off" data-search-query="AOCE" data-search-type="attr" type="checkbox" value="AOCE"/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-flex">
#             Flexible Classes
#            </a>
#            <div class="collapse" id="filter-flex">
#             <label class="btn btn-light btn-sm mr-1">
#              FLXU
#              <input autocomplete="off" data-search-query="FLXU" data-search-type="attr" type="checkbox" value="FLXU"/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-other-codes">
#             Other Course Attributes
#            </a>
#            <div class="collapse" id="filter-other-codes">
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               AOCE
#              </span>
#              <input autocomplete="off" data-search-query="AOCE" data-search-type="attr" type="checkbox" value="AOCE"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               CEL
#              </span>
#              <input autocomplete="off" data-search-query="CEL" data-search-type="attr" type="checkbox" value="CEL"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               CLAC
#              </span>
#              <input autocomplete="off" data-search-query="CLAC" data-search-type="attr" type="checkbox" value="CLAC"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               EGLA
#              </span>
#              <input autocomplete="off" data-search-query="EGLA" data-search-type="attr" type="checkbox" value="EGLA"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               FLXU
#              </span>
#              <input autocomplete="off" data-search-query="FLXU" data-search-type="attr" type="checkbox" value="FLXU"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               HON
#              </span>
#              <input autocomplete="off" data-search-query="HON" data-search-type="attr" type="checkbox" value="HON"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               LEAP
#              </span>
#              <input autocomplete="off" data-search-query="LEAP" data-search-type="attr" type="checkbox" value="LEAP"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               OMBA
#              </span>
#              <input autocomplete="off" data-search-query="OMBA" data-search-type="attr" type="checkbox" value="OMBA"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               PACE
#              </span>
#              <input autocomplete="off" data-search-query="PACE" data-search-type="attr" type="checkbox" value="PACE"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               PMBA
#              </span>
#              <input autocomplete="off" data-search-query="PMBA" data-search-type="attr" type="checkbox" value="PMBA"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               SUSC
#              </span>
#              <input autocomplete="off" data-search-query="SUSC" data-search-type="attr" type="checkbox" value="SUSC"/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               SUSL
#              </span>
#              <input autocomplete="off" data-search-query="SUSL" data-search-type="attr" type="checkbox" value="SUSL"/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-type">
#             Type
#            </a>
#            <div class="collapse" id="filter-type">
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               Hybrid
#              </span>
#              <input autocomplete="off" data-search-query="H" data-search-type="type" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               Hybrid &amp; IVC
#              </span>
#              <input autocomplete="off" data-search-query="IH" data-search-type="type" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               In Person
#              </span>
#              <input autocomplete="off" data-search-query="P" data-search-type="type" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               Interactive Video Conferencing
#              </span>
#              <input autocomplete="off" data-search-query="I" data-search-type="type" type="checkbox" value=""/>
#             </label>
#             <label class="btn btn-light btn-sm mr-1">
#              <span>
#               Online
#              </span>
#              <input autocomplete="off" data-search-query="O" data-search-type="type" type="checkbox" value=""/>
#             </label>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-units">
#             Units
#            </a>
#            <div class="collapse" id="filter-units">
#             <div id="slider">
#              <div class="ui-slider-handle" id="custom-handle">
#              </div>
#             </div>
#             <input autocomplete="off" data-search-type="units" id="unit-slider" type="checkbox" value=""/>
#            </div>
#            <a class="expanding-link list-group-item" data-parent="#filter-controls" data-toggle="collapse" href="#filter-seats">
#             Seats Available
#            </a>
#            <div class="collapse" id="filter-seats">
#             <label class="btn btn-light btn-sm">
#              Seats Available
#              <input autocomplete="off" data-search-query="true" data-search-type="seats" type="checkbox" value=""/>
#             </label>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col">
#       <!-- ************* MAIN CONTENT AREA ****************** -->
#       <main id="uu-skip-target" role="main">
#        <div>
#         <div class="row">
#          <div class="col-xl-7">
#           <div class="card mt-3">
#            <div class="card-header" scope="col">
#             Departmental Advisors
#            </div>
#            <div class="card-body">
#             <div class="row mt-2">
#              <div class="col text-left">
#               Undergraduate Studies Office
#              </div>
#              <div class="col text-left">
#               Vicki Jackson
#              </div>
#              <div class="col-xl-6 text-left">
#               MEB 3190
#              </div>
#             </div>
#             <div class="row mt-2">
#              <div class="col text-left">
#               Graduate Studies Office
#              </div>
#              <div class="col text-left">
#               Jill Wilson
#              </div>
#              <div class="col-xl-6 text-left">
#               MEB 3190
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="card">
#            <div class="card-body">
#             <a class="btn btn-primary" href="https://ctle.utah.edu/scf/reports/student" target="_blank">
#              View Course Feedback
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="col">
#           <div class="card mt-3">
#            <div class="card-header">
#             Departmental Notes
#            </div>
#            <div class="card-body">
#             <p>
#              <span>
#               For course descriptions and pre-requisite information click on the subject column next to the appropriate catalog number.
#              </span>
#             </p>
#             <p>
#              <span>
#               THIS DEPARTMENT ENFORCES UNDERGRADUATE PREREQUISITES. Please note that the registration system may not factor in transfer work when determining if prerequisites have been met.   If you are unable to register for a course and think you have met the prerequisite(s), please contact an advisor from this department to inquire about obtaining a permission code.  You may be administratively dropped from a course if the prerequisite has not been met.
#              </span>
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="alert alert-secondary mt-3" role="alert">
#         <span class="allcaps">
#          Attention:
#         </span>
#         Classroom assignments may change between the time you
#                     register and when classes begin. Please check your class schedule for the latest classroom location
#                     information before attending class.
#        </div>
#        <!-- Class Details Table -->
#        <div id="class-details">
#         <div class="class-info card mt-3" id="18034">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1030&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1030">
#              CS 1030
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <a href="https://utah.instructure.com/courses/840025/assignments/syllabus">
#              Foundations of CS
#             </a>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="18034">
#              </a>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">
#                PARKER, ERIN
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Lecture
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U3_0">
#              Units:
#              <span>
#               3.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               8
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1030">
#              CS 1030
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <a href="https://utah.instructure.com/courses/840025/assignments/syllabus">
#              Foundations of CS
#             </a>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="18034">
#              </a>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">
#                PARKER, ERIN
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Lecture
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U3_0">
#              Units:
#              <span>
#               3.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               8
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1030&amp;section=001">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="MoWe">
#                  MoWe
#                 </span>
#                 /
#                 <span data-time="M">
#                  11:50AM-01:10PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="WEB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">
#                  WEB 1230
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="18035">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1030&amp;section=002">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1030">
#              CS 1030
#             </a>
#             -
#             <span>
#              002
#             </span>
#             <span>
#              Foundations of CS
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="18035">
#              </a>
#              <span>
#               18035
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">
#                PARKER, ERIN
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Laboratory
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U-U-U">
#              Units:
#              <span>
#               --
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               4
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1030">
#              CS 1030
#             </a>
#             -
#             <span>
#              002
#             </span>
#             <span>
#              Foundations of CS
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="18035">
#              </a>
#              <span>
#               18035
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">
#                PARKER, ERIN
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Laboratory
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U-U-U">
#              Units:
#              <span>
#               --
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               4
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1030&amp;section=002">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="Th">
#                  Th
#                 </span>
#                 /
#                 <span data-time="M">
#                  09:40AM-10:30AM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="SFEBB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=SFEBB" target="_blank">
#                  SFEBB 5160B
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="18036">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1030&amp;section=003">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1030">
#              CS 1030
#             </a>
#             -
#             <span>
#              003
#             </span>
#             <span>
#              Foundations of CS
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="18036">
#              </a>
#              <span>
#               18036
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">
#                PARKER, ERIN
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Laboratory
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U-U-U">
#              Units:
#              <span>
#               --
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               4
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1030">
#              CS 1030
#             </a>
#             -
#             <span>
#              003
#             </span>
#             <span>
#              Foundations of CS
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="18036">
#              </a>
#              <span>
#               18036
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">
#                PARKER, ERIN
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Laboratory
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U-U-U">
#              Units:
#              <span>
#               --
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               4
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1030&amp;section=003">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="Th">
#                  Th
#                 </span>
#                 /
#                 <span data-time="M">
#                  10:45AM-11:35AM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="SFEBB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=SFEBB" target="_blank">
#                  SFEBB 5160B
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="14354">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=1400&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=1400">
#              CS 1400
#             </a>
#             -
#             <span>
#              001
#             </span>
# ...
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0684549/teaching/index.hml" target="_blank">
#                PHILLIPS, JEFF
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u6024891/teaching/index.hml" target="_blank">
#                Sullivan, Blair
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               16
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7941&amp;section=001">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="We">
#                  We
#                 </span>
#                 /
#                 <span data-time="M">
#                  10:30AM-11:45AM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">
#                  MEB 3147
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="7375">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7942&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7942">
#              CS 7942
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Visualization Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="7375">
#              </a>
#              <span>
#               7375
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0030676/teaching/index.hml" target="_blank">
#                JOHNSON, CHRISTOPHER
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               19
#              </span>
#             </li>
#            </ul>
#            <hr>
#             <span>
#              This class meets in WEB 3780.
#             </span>
#            </hr>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7942">
#              CS 7942
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Visualization Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="7375">
#              </a>
#              <span>
#               7375
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u0030676/teaching/index.hml" target="_blank">
#                JOHNSON, CHRISTOPHER
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               19
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7942&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <hr class="class-notes-divider"/>
#            <span>
#             This class meets in WEB 3780.
#            </span>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="We">
#                  We
#                 </span>
#                 /
#                 <span data-time="A">
#                  12:00PM-01:00PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="TBA" scope="row">
#                 <span>
#                  TBA .
#                 </span>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="class-info card mt-3" id="11209">
#          <div class="card-body row d-none d-md-block">
#           <div class="col-12 p-0">
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7944&amp;section=001">
#              Class Details
#             </a>
#            </div>
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7944">
#              CS 7944
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Comp Narrative Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row breadcrumb-list list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a id="11209">
#              </a>
#              <span>
#               11209
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u6014318/teaching/index.hml" target="_blank">
#                Cardona-Rivera, Rogelio E
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u6006841/teaching/index.hml" target="_blank">
#                YOUNG, Michael M
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto d-none" data-seats="true">
#              Seats Available:
#              <span>
#               19
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="card-body row d-block d-md-none">
#           <div class="col-12 p-0">
#            <h3>
#             <a href="sections.html?subj=CS&amp;catno=7944">
#              CS 7944
#             </a>
#             -
#             <span>
#              001
#             </span>
#             <span>
#              Comp Narrative Seminar
#             </span>
#            </h3>
#           </div>
#           <div class="col-12 p-0">
#            <ul class="row list-unstyled">
#             <li class="col-sm-auto">
#              Class Number:
#              <a name="11209">
#              </a>
#              <span>
#               11209
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u6014318/teaching/index.hml" target="_blank">
#                Cardona-Rivera, Rogelio E
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Instructor:
#              <span>
#               <a href="http://faculty.utah.edu/u6006841/teaching/index.hml" target="_blank">
#                YOUNG, Michael M
#               </a>
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Component:
#              <span>
#               Seminar
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Type:
#              <span data-type="P">
#               In Person
#              </span>
#             </li>
#             <li class="col-sm-auto" data-units="U1_0">
#              Units:
#              <span>
#               1.0
#              </span>
#             </li>
#             <li class="col-sm-auto">
#              Requisites: Yes
#             </li>
#             <li class="col-sm-auto">
#              Wait List:
#              <span>
#               No
#              </span>
#             </li>
#             <li class="col-sm-auto" data-seats="true">
#              Seats Available:
#              <span>
#               19
#              </span>
#             </li>
#            </ul>
#            <div class="buttons">
#             <a class="btn btn-secondary btn-sm" href="description.html?subj=CS&amp;catno=7944&amp;section=001">
#              Class Details
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="card-footer mp-1">
#           <div class="row mb-2">
#            <div class="col">
#             <table class="table time-table">
#              <thead class="class-cards table minimal-headers">
#               <tr>
#                <th class="text-nowrap text-left text-muted h6 p-0" scope="col">
#                 Days / Times
#                </th>
#                <th class="text-nowrap text-right text-muted h6 p-0" scope="col">
#                 Locations
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <th class="text-nowrap text-left p-0" scope="row">
#                 <span data-day="Mo">
#                  Mo
#                 </span>
#                 /
#                 <span data-time="M">
#                  11:00AM-12:00PM
#                 </span>
#                </th>
#                <th class="text-nowrap text-right p-0" data-building-code="MEB" scope="row">
#                 <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">
#                  MEB 3485
#                 </a>
#                </th>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="row mt-3">
#         <div class="col text-center">
#          <a href="seating_availability.html?subject=CS">
#           Seating availability for all CS classes
#          </a>
#         </div>
#        </div>
#       </main>
#       <!-- ************** END MAIN CONTENT AREA ************** -->
#      </div>
#     </div>
#    </section>
#    <!--*** END OF CONTENT ***-->
#    <a aria-label="Back to top" href="#back-to-top" id="back-to-top" title="Back to top">
#     <i class="fas fa-arrow-up">
#     </i>
#    </a>
#   </div>
#   <!--*** START OF FOOTER ***-->
#   <footer class="bg-secondary mt-5 pb-5 d-flex flex-column">
#    <div class="container-fluid px-4 px-sm-5 py-4">
#     <div class="row">
#      <div class="col-sm-6 col-md-4 small text-light">
#       <p>
#        University Support Services
#        <br/>
#        102 S 200 E, Ste. 100
#        <br/>
#        Salt Lake City, UT 84111
#       </p>
#       <p>
#        <a class="text-light" href="http://www.utah.edu">
#         © The University of Utah
#        </a>
#       </p>
#      </div>
#      <div class="col-sm-6 col-md-4 small">
#       <p>
#        <a class="text-light" href="http://www.utah.edu/nondiscrimination/">
#         Nondiscrimination &amp; Accessibility
#        </a>
#        <br/>
#        <a class="text-light" href="http://www.utah.edu/disclaimer/">
#         Disclaimer
#        </a>
#        <br/>
#        <a class="text-light" href="http://www.utah.edu/privacy/">
#         Privacy
#        </a>
#        <br/>
#       </p>
#      </div>
#      <div class="col-sm-12 col-md-4">
#       <a href="https://imagineu.utah.edu/" target="_blank">
#        <img alt="The University of Utah - Imagine U" class="footer-logo" src="/uofu/stu/ClassSchedules/images/imagine_u.png"/>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!--*** END OF FOOTER ***-->
#  </body>
# </html>

# %% [markdown]
# Now, let's analyze this html in the inspector.

# %% [markdown]
# ![Class Site Inspected](class.png)
#
#
#
# The data is stored in a table that has the ID `classDetailsTable`. Here is the relevant section for an individual class:
#
#
# ```html
# <h3>
# <a href="sections.html?subj=CS&amp;catno=1030">CS 1030</a>
#                         -
#                         <span>001</span>
# <a href="https://utah.instructure.com/courses/673272/assignments/syllabus">Foundations of CS</a>
# </h3>
# ```
#
# Let's extract this information:

# %%
import pandas as pd

# to remove duplicates
course_numbers = set();
# we'll store the data here 
course_rows = []

# here we get the ".card-body" children of the element with the #class-details id; 
# this returns a list of soup objects that contain the relevant info for each class.
course_container = class_soup.select("#class-details .card-body")

for course in course_container:
    # print(course)
    
    # we get the link that is part of a heading 3 element and retrieve the first one
    course_info = course.select("h3")[0].get_text()
    # print(course_info)
    
    # The first one has two links, duplicate courses (sections) sometimes have only one. 
    number, name = course_info.split(" -")[0:2]
    # get rid of white space
    number = number.strip()
    # the name is of the format "001\nNetworking Seminar\n'" We get rid of the section number.
    name = name.strip()[4:]
    #print(number, name)
    
    # Avoid the duplicates
    if(number in course_numbers):
        continue
    course_numbers.add(number)

    # get the URL 
    link = url + course.select("h3 a")[0].get("href")
    
    # the course info is contained in a unordered list. Here we get the list items. 
    info_list = course.select("ul li")
    # print(info_list)
    
    # here we get the second element that contains the instructor information, get the text, and split it by : 
    instructor = info_list[1].get_text().split(":")[1]
    # more cleanup - we keep the stuff before the - and then clear up the whitespace
    instructor = instructor.split("-")[0].strip()
           
    #print(number, name, link, instructor)

    # We store this as a dictionary in our course_rows lists. 
    # The dictionary is well suited to later initialize a data frame
    course_rows.append({"Number":number, "Name":name, "Instructor":instructor, "Link":link, "Students":0})  
    
    
# create the data frame    
courses = pd.DataFrame(course_rows)    
    
courses.head(15)
# Out:
#      Number                     Name                     Instructor  \
# 0   CS 1030        Foundations of CS                   PARKER, ERIN
# 1   CS 1400   Intro Comp Programming                 JOHNSON, DAVID
# 2   CS 1410     Object-Oriented Prog               MARTIN, TRAVIS B
# 3   CS 1420    Accel Obj-Orient Prog                  JENSEN, PETER
# 4   CS 2100      Discrete Structures              Elhabian, Shireen
# 5   CS 2420  Intro Alg & Data Struct                     JONES, BEN
# 6   CS 3011           Industry Forum                  CARP, SHERI L
# 7   CS 3090      Ethics in Computing               MARTIN, TRAVIS B
# 8   CS 3100    Models Of Computation                   WANG, HAITAO
# 9   CS 3130           Eng Prob Stats                 PHILLIPS, JEFF
# 10  CS 3200           Intro Sci Comp                BERZINS, MARTIN
# 11  CS 3500        Software Practice  DE ST GERMAIN, H. JAMES 'JIM'
# 12  CS 3505     Software Practice II                 JOHNSON, DAVID
# 13  CS 3540  Design Human Center Exp                WIESE, ELIANE S
# 14  CS 3700    Digital System Design                 KALLA, PRIYANK
#
#                                                  Link  Students
# 0   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 1   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 2   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 3   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 4   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 5   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 6   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 7   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 8   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 9   https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 10  https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 11  https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 12  https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 13  https://student.apps.utah.edu/uofu/stu/ClassSc...         0
# 14  https://student.apps.utah.edu/uofu/stu/ClassSc...         0

# %% [markdown]
# Now we can ask questions, such as who's teaching the most students.

# %%
courses["Instructor"].value_counts()
# Out:
# JOHNSON, CHRISTOPHER             3
# PARKER, ERIN                     2
# KASERA, SNEHA K                  2
# WIESE, JASON                     2
# JOHNSON, DAVID                   2
# GOPALAKRISHNAN, GANESH           2
# MARASOVIC, ANA                   2
# SRIKUMAR, VIVEK                  2
# BURTSEV, ANTON                   2
# YUKSEL, CEM                      2
# KOPTA, DANIEL                    2
# SNELGROVE, ASHTON                2
# PANDEY, PRASHANT                 2
# LEX, ALEXANDER                   2
# KUNTZ, ALAN                      2
# YANG, YIN                        2
# HALL, MARY W                     2
# STEVENS, KENNETH S               2
# BALASUBRAMONIAN, RAJEEV          2
# PHILLIPS, JEFF                   2
# MARTIN, TRAVIS B                 2
# RILOFF, ELLEN                    1
# Zhe, Shandian                    1
# BROWN, DANIEL S                  1
# HERMANS, TUCKER                  1
# MASCARO, STEPHEN A               1
# JENSEN, PETER                    1
# Sundar, Hari                     1
# Elhabian, Shireen                1
# HENDERSON, THOMAS                1
# Zhang, Mu                        1
# AL HALAH, ZIAD                   1
# KOGAN, MARINA                    1
# EIDE, ERIC N                     1
# TASDIZEN, TOLGA                  1
# ROSEN, PAUL                      1
# JONES, BEN                       1
# NAGY, STEFAN                     1
# CARP, SHERI L                    1
# WANG, HAITAO                     1
# BERZINS, MARTIN                  1
# DE ST GERMAIN, H. JAMES 'JIM'    1
# WIESE, ELIANE S                  1
# KALLA, PRIYANK                   1
# PHILLIPS, BEI WANG               1
# BRUNVAND, ERIK                   1
# DE ST GERMAIN, JOHN              1
# SHANKAR, VARUN                   1
# BEAN, DAVID                      1
# STUTSMAN, RYAN                   1
# PANCHEKHA, PAVEL                 1
# Cardona                          1
# Name: Instructor, dtype: int64

# %% [markdown]
# ### Counting Enrollment
#
# Now let's look at which classes have the most students. Here's an example for the [Algorithms and Data Structures class](https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1214/sections.html?subj=CS&catno=2420).
#
# Let's scrape the number of students from this website.
#
# The data is contained in a `<table>`. When we have a table, there is an easy way to get the data out – use the magic of Pandas data import functions. There is a sophisticated [`read_html()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html) function.
#
# Behind the scenes, this uses html5lib, which should be part of your anaconda installation, but if not, you will have to install it:
#
# ```
# conda install -c anaconda html5lib
# ```
#
# Once installed, we can pass in the table as a string:

# %%
enrollment_url = "https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1234/sections.html?subj=CS&catno=2420"
with urllib.request.urlopen(enrollment_url) as response:
    class_student_html = response.read()
class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
# we use pandas to read the table, this returns an array of dataframes, we take the first table
student_ar = pd.read_html(str(class_student_soup))[0]
student_ar.head()
# Out:
#    Class # Subject  Catalog #  Section                    Title  \
# 0     5404      CS       2420        1  Intro Alg & Data Struct
# 1     5405      CS       2420        2  Intro Alg & Data Struct
# 2     5406      CS       2420        3  Intro Alg & Data Struct
# 3     5407      CS       2420        4  Intro Alg & Data Struct
# 4     5408      CS       2420        5  Intro Alg & Data Struct
#
#    Enrollment Cap  Wait List  Currently Enrolled  Seats Available
# 0             399          0                 398                1
# 1              31          0                  31                0
# 2              31          0                  28                3
# 3              31          0                  32               -1
# 4              31          0                  33               -2

# %% [markdown]
# Now, we can retrieve the student number; most classes have one "overall" section (section 1), and further sections for recitations. So we'll just use the first.

# %%
students = student_ar["Currently Enrolled"][0]
students
# Out:
# 398

# %% [markdown]
# Let's pack this all up in a function that takes the URL and returns the number:

# %%
def scrape_students(url):
    """
    Retreive the number of students from the table on the website specified in the URL
    """
    with urllib.request.urlopen(url) as response:
        class_student_html = response.read()
    class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
    # we use pandas to read the table
    student_df = pd.read_html(str(class_student_soup))[0]
    students = student_df["Currently Enrolled"][0]
    return students

# %% [markdown]
# And run this for all the courses from the data structure that we built before using the apply function.
#
# Note that this actually accesses the websites and thus takes a while.

# %%
courses["Students"] = courses["Link"].apply(scrape_students)

# %% [markdown]
# Now let's look at which are the largest classes:

# %%
courses = courses.sort_values("Students", ascending=False)
courses = courses.reset_index(drop=True)
courses.head(25)
# Out:
#      Number                          Name                     Instructor  \
# 0   CS 2420       Intro Alg & Data Struct                     JONES, BEN
# 1   CS 3500             Software Practice  DE ST GERMAIN, H. JAMES 'JIM'
# 2   CS 1410          Object-Oriented Prog               MARTIN, TRAVIS B
# 3   CS 2100           Discrete Structures              Elhabian, Shireen
# 4   CS 3130                Eng Prob Stats                 PHILLIPS, JEFF
# 5   CS 5530              Database Systems                  KOPTA, DANIEL
# 6   CS 3810         Computer Organization        BALASUBRAMONIAN, RAJEEV
# 7   CS 3505          Software Practice II                 JOHNSON, DAVID
# 8   CS 1420         Accel Obj-Orient Prog                  JENSEN, PETER
# 9   CS 4400              Computer Systems                  KOPTA, DANIEL
# 10  CS 1400        Intro Comp Programming                 JOHNSON, DAVID
# 11  CS 4530        Mobile App Programming                 SHANKAR, VARUN
# 12  CS 4150                    Algorithms                   Sundar, Hari
# 13  CS 4440             Computer Security                   NAGY, STEFAN
# 14  CS 4480             Computer Networks                 STUTSMAN, RYAN
# 15  CS 3100         Models Of Computation                   WANG, HAITAO
# 16  CS 4500       Senior Capstone Project                    BEAN, DAVID
# 17  CS 3200                Intro Sci Comp                BERZINS, MARTIN
# 18  CS 3011                Industry Forum                  CARP, SHERI L
# 19  CS 3090           Ethics in Computing               MARTIN, TRAVIS B
# 20  CS 4000        Senior Capstone Design            DE ST GERMAIN, JOHN
# 21  CS 6635       Vis for Scientific Data           JOHNSON, CHRISTOPHER
# 22  CS 1030             Foundations of CS                   PARKER, ERIN
# 23  CS 6956  Software and System Security                      Zhang, Mu
# 24  CS 6460             Operating Systems                 BURTSEV, ANTON
#
#                                                  Link  Students
# 0   https://student.apps.utah.edu/uofu/stu/ClassSc...       398
# 1   https://student.apps.utah.edu/uofu/stu/ClassSc...       294
# 2   https://student.apps.utah.edu/uofu/stu/ClassSc...       250
# 3   https://student.apps.utah.edu/uofu/stu/ClassSc...       243
# 4   https://student.apps.utah.edu/uofu/stu/ClassSc...       231
# 5   https://student.apps.utah.edu/uofu/stu/ClassSc...       228
# 6   https://student.apps.utah.edu/uofu/stu/ClassSc...       218
# 7   https://student.apps.utah.edu/uofu/stu/ClassSc...       204
# 8   https://student.apps.utah.edu/uofu/stu/ClassSc...       195
# 9   https://student.apps.utah.edu/uofu/stu/ClassSc...       194
# 10  https://student.apps.utah.edu/uofu/stu/ClassSc...       184
# 11  https://student.apps.utah.edu/uofu/stu/ClassSc...       170
# 12  https://student.apps.utah.edu/uofu/stu/ClassSc...       169
# 13  https://student.apps.utah.edu/uofu/stu/ClassSc...       159
# 14  https://student.apps.utah.edu/uofu/stu/ClassSc...       155
# 15  https://student.apps.utah.edu/uofu/stu/ClassSc...       116
# 16  https://student.apps.utah.edu/uofu/stu/ClassSc...       101
# 17  https://student.apps.utah.edu/uofu/stu/ClassSc...        84
# 18  https://student.apps.utah.edu/uofu/stu/ClassSc...        78
# 19  https://student.apps.utah.edu/uofu/stu/ClassSc...        76
# 20  https://student.apps.utah.edu/uofu/stu/ClassSc...        72
# 21  https://student.apps.utah.edu/uofu/stu/ClassSc...        54
# 22  https://student.apps.utah.edu/uofu/stu/ClassSc...        52
# 23  https://student.apps.utah.edu/uofu/stu/ClassSc...        48
# 24  https://student.apps.utah.edu/uofu/stu/ClassSc...        47

# %% [markdown]
# The algorithms class is the biggest one, followed by the database class.

# %% [markdown]
# Now, we want to answer the question **at which level are the most students enrolled in CS?** Levels are the leading digit of the course number and roughly correspond to the year you're supposed to take a class. 5000 level classes are advanced undergrad classes, often cross-listed with grad classes. 6000 classes are graduate classes, 7000 classes are seminars and other PhD level classes. Let's create a new column level and add it to the dataframe:

# %%
# we use x[3] because the strings such as "CS 1410" have the level digit at index 3
courses["level"] = courses["Number"].map(lambda x: x[3])
courses = courses.sort_values(by="level")
courses.head(100)
# Out:
#      Number                      Name               Instructor  \
# 10  CS 1400    Intro Comp Programming           JOHNSON, DAVID
# 8   CS 1420     Accel Obj-Orient Prog            JENSEN, PETER
# 22  CS 1030         Foundations of CS             PARKER, ERIN
# 2   CS 1410      Object-Oriented Prog         MARTIN, TRAVIS B
# 3   CS 2100       Discrete Structures        Elhabian, Shireen
# ..      ...                       ...                      ...
# 38  CS 7941      Data Science Seminar           PHILLIPS, JEFF
# 59  CS 7932  Human-Centered Computing            KOGAN, MARINA
# 51  CS 7942     Visualization Seminar     JOHNSON, CHRISTOPHER
# 64  CS 7937                 Arch/VLSI  BALASUBRAMONIAN, RAJEEV
# 48  CS 7939          Robotics Seminar              KUNTZ, ALAN
#
#                                                  Link  Students level
# 10  https://student.apps.utah.edu/uofu/stu/ClassSc...       184     1
# 8   https://student.apps.utah.edu/uofu/stu/ClassSc...       195     1
# 22  https://student.apps.utah.edu/uofu/stu/ClassSc...        52     1
# 2   https://student.apps.utah.edu/uofu/stu/ClassSc...       250     1
# 3   https://student.apps.utah.edu/uofu/stu/ClassSc...       243     2
# ..                                                ...       ...   ...
# 38  https://student.apps.utah.edu/uofu/stu/ClassSc...        24     7
# 59  https://student.apps.utah.edu/uofu/stu/ClassSc...         6     7
# 51  https://student.apps.utah.edu/uofu/stu/ClassSc...        11     7
# 64  https://student.apps.utah.edu/uofu/stu/ClassSc...         2     7
# 48  https://student.apps.utah.edu/uofu/stu/ClassSc...        15     7
#
# [74 rows x 6 columns]

# %% [markdown]
# We can calculate the answer with groupby:

# %%
import numpy as np
student_stats = courses.groupby("level").aggregate(["count", np.sum, np.mean, np.std])
student_stats
# Out:
# C:\Users\lissa\AppData\Local\Temp\ipykernel_17728\3845212102.py:2: FutureWarning: ['Number', 'Name', 'Instructor', 'Link'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   student_stats = courses.groupby("level").aggregate(["count", np.sum, np.mean, np.std])
#       Students
#          count   sum        mean         std
# level
# 1            4   681  170.250000   83.953856
# 2            2   641  320.500000  109.601551
# 3           12  1376  114.666667   98.047607
# 4           12  1078   89.833333   76.580122
# 5           10   424   42.400000   67.201521
# 6           25   559   22.360000   15.994478
# 7            9    75    8.333333    8.000000

# %% [markdown]
# Let's visualize this with box and overlaid strip plots:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc={'figure.figsize':(15,8)})

# there isn't enough data for a violin plot to work well. 
ax = sns.boxplot(data=courses, x="level", y="Students", fliersize=0)
ax = sns.stripplot(data=courses, x="level", y="Students", color="black", alpha=0.5, size=10)

#props = dict(linewidth=2)
# here we group by level
#courses.boxplot(by='level', figsize=(10, 10),  boxprops=props, medianprops=props, whiskerprops=props, capprops=props)

# %% [markdown]
# And plot a bar chart for the number of students at each level:

# %%
student_sum = courses.groupby("level").aggregate([np.sum])
student_sum.plot.bar(legend=False, figsize=(15, 8))
# Out:
# <AxesSubplot:xlabel='level'>

# %% [markdown]
# We can see that the most students are in the 3000 level.

# %% [markdown]
# ## Scraping Wrap-Up
#
# Scraping is a way to get information from website that were not designed to make data accessible. As such, it can often be **brittle**: a website change will break your scraping script. It is also often not welcome, as a scaper can cause a lot of traffic.
#
# The way we scraped information here also made the **assumption that HTML is generated consistently** based just on the URL. That is, unfortunately, less and less common, as websites adapt to browser types, resolutions, locales, but also as a lot of content is loaded dynamically e.g., via web-sockets. For example, many websites now auotmatically load more data once you scroll to the bottom of the page. These websites couldn't be scraped with our approach, instead, a browser-emulation approach, using e.g., [Selenium](https://www.selenium.dev/) would be necessary. [Here is a tutorial](https://medium.com/the-andela-way/introduction-to-web-scraping-using-selenium-7ec377a8cf72) on how to do that.
#
# Finally, many services make their data available through a well-defined interface, an API. Using an API is always a better idea than scraping, but scraping is a good fallback!
